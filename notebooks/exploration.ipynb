# %% [markdown]
# # HMM Portfolio Exploration
#
# I love exploring data. It's like being a detective, but with numbers instead of fingerprints.
# In this notebook, we'll walk through the main components of the HMM-driven portfolio engine.

# %%
import sys
sys.path.append('..')
import pandas as pd
from src.data_loader import load_config
from src.features import calculate_features

config = load_config('../config.yaml')
print("Config loaded successfully!")
